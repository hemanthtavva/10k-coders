# %%
#os module - operating system is used to perform operating system related tasks like 
# creating, removing, changing directories, fetching its contents, etc.

# %%
import os

# %%
#current working directory
print(os.getcwd()) # get current working directory
# Out:
# /Users/hemanthtavva/Desktop/10k coders/python

# %%
#change directory
#cd.. is one way to go back to the previous directory
print(os.getcwd(), "before changing directory")
os.chdir("/Users/hemanthtavva/Desktop/10k coders/python/os")
print(os.getcwd(), "after changing directory")
# Out:
# /Users/hemanthtavva/Desktop/10k coders/python before changing directory
# /Users/hemanthtavva/Desktop/10k coders/python/os after changing directory

# %%
#list directory contents is used to list the components of a directory.
os.listdir("/Users/hemanthtavva/Desktop/10k_coders/python")
# Out:
# ['patternn.py',
#  'pdbc.ipynb',
#  'dictonary.ipynb',
#  'random_1.py',
#  'assignments',
#  '.DS_Store',
#  'comprehension.ipynb',
#  'sets.ipynb',
#  'file handling',
#  'db.ipynb',
#  'problem_solving.ipynb',
#  'lists.ipynb',
#  '__pycache__',
#  'time.ipynb',
#  'functions.ipynb',
#  'recursion.ipynb',
#  'anonymous.ipynb',
#  'patterns.ipynb',
#  'os',
#  'strings.ipynb',
#  'sclicing.ipynb',
#  'random.ipynb',
#  'scope.ipynb',
#  '.git']

# %%
#make a new directory
os.makedirs("newdir") # create a new directory

# %%
#remove a folder, we can not remove it since we need some particular perimissions to remove a folder.
os.remove("newdir") # remove a file
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 os.remove("newdir") # remove a file
#
# PermissionError: [Errno 1] Operation not permitted: 'newdir'

# %%
#remove a directory file
os.remove("/Users/hemanthtavva/Desktop/10k_coders/python/os/newdir/del.py")

# %%
#rename a file
os.rename("/Users/hemanthtavva/Desktop/10k_coders/python/os/os.ipynb", "/Users/hemanthtavva/Desktop/10k_coders/python/os/os_module.ipynb") # rename a file

# %%
if os.path.exists("/Users/hemanthtavva/Desktop/10k_coders/python/os/os_module.ipynb"):
    print("File exists")
# Out:
# File exists

# %%
if os.path.exists("/Users/hemanthtavva/Desktop/10k_coders/python/os/os_module.ipynb"):
    os.rename("/Users/hemanthtavva/Desktop/10k_coders/python/os/os_module.ipynb", "/Users/hemanthtavva/Desktop/10k_coders/python/os/os.ipynb") # rename a file

# %%
#abspath or absolute path is used to get the absolute path of a file.
print(os.path.abspath("./"))
# Out:
# /Users/hemanthtavva/Desktop/10k_coders/python/os

# %%
if os.path.abspath("./")[1] == "U":
    print("users")
else:
    print("not users")
# Out:
# users

# %%
print(os.path.basename(os.path.abspath("./")))
# Out:
# os

# %%
print(os.path.basename("/Users/hemanthtavva/Desktop/10k_coders/python/os/os.ipynb")) 
# get the base name of a file
# Out:
# os.ipynb

# %%
print(os.path.dirname("/Users/hemanthtavva/Desktop/10k_coders/python/os/os.ipynb")) 
# get the directory name of a file
# Out:
# /Users/hemanthtavva/Desktop/10k_coders/python/os

# %%
print(os.path.dirname("/Users/hemanthtavva/Desktop/10k_coders/python/os")) 
# get the directory name of a file
# Out:
# /Users/hemanthtavva/Desktop/10k_coders/python

# %%
print(os.path.isdir("/Users/hemanthtavva/Desktop/10k_coders/python/os")) 
# check if the path is a directory
# Out:
# True

# %%
print(os.path.isfile("/Users/hemanthtavva/Desktop/10k_coders/python/os/os.ipynb"))
 # check if the path is a file
# Out:
# True

# %%
print(os.path.getsize("/Users/hemanthtavva/Desktop/10k_coders/python/os/os.py")) 
# get the size of a file
# Out:
# 259

# %%
from pathlib import Path

for f in Path('/Users/hemanthtavva/Desktop/10k_coders/python').glob('*.ipynb'):
    print(f)
# Out:
# /Users/hemanthtavva/Desktop/10k_coders/python/pdbc.ipynb
# /Users/hemanthtavva/Desktop/10k_coders/python/dictonary.ipynb
# /Users/hemanthtavva/Desktop/10k_coders/python/comprehension.ipynb
# /Users/hemanthtavva/Desktop/10k_coders/python/sets.ipynb
# /Users/hemanthtavva/Desktop/10k_coders/python/db.ipynb
# /Users/hemanthtavva/Desktop/10k_coders/python/problem_solving.ipynb
# /Users/hemanthtavva/Desktop/10k_coders/python/lists.ipynb
# /Users/hemanthtavva/Desktop/10k_coders/python/time.ipynb
# /Users/hemanthtavva/Desktop/10k_coders/python/functions.ipynb
# /Users/hemanthtavva/Desktop/10k_coders/python/recursion.ipynb
# /Users/hemanthtavva/Desktop/10k_coders/python/anonymous.ipynb
# /Users/hemanthtavva/Desktop/10k_coders/python/patterns.ipynb
# /Users/hemanthtavva/Desktop/10k_coders/python/strings.ipynb
# /Users/hemanthtavva/Desktop/10k_coders/python/sclicing.ipynb
# /Users/hemanthtavva/Desktop/10k_coders/python/random.ipynb
# /Users/hemanthtavva/Desktop/10k_coders/python/scope.ipynb

# %%
for i in Path('.').iterdir():
    if i.is_file():
        print(i.name)
# Out:
# os.py
# os.ipynb
