# %%
import pandas as pd

# %% [markdown]
# ##Task -1

# %%
marks = pd.Series(
   [78, 92, 65, 88, 74, 95],
   index=["S101", "S102", "S103", "S104", "S105", "S106"],
   name="Marks"
)

# %%
#1
print(marks)
# Out:
# S101    78
# S102    92
# S103    65
# S104    88
# S105    74
# S106    95
# Name: Marks, dtype: int64

# %%
#2
print(marks.index)
# Out:
# Index(['S101', 'S102', 'S103', 'S104', 'S105', 'S106'], dtype='object')

# %%
print(marks.values)
# Out:
# [78 92 65 88 74 95]

# %%
print(marks.dtype)
# Out:
# int64

# %%
print(marks.shape)
# Out:
# (6,)

# %%
print(marks.size)
# Out:
# 6

# %%
print(marks.ndim)
# Out:
# 1

# %%
print(marks.name)
# Out:
# Marks

# %%
#3
print(marks.mean())
# Out:
# 82.0

# %%
#4
print(marks.max())
# Out:
# 95

# %%
#5
print(marks.idxmax())
# Out:
# S106

# %%
#6
print(marks[marks>80])
# Out:
# S102    92
# S104    88
# S106    95
# Name: Marks, dtype: int64

# %%
marks.iloc[0:3]
# Out:
# S101    78
# S102    92
# S103    65
# Name: Marks, dtype: int64

# %%
print(marks.loc["S104"])
# Out:
# 88

# %%
#challenge
total = marks.sum()
per= (marks/total) *100
print(per)
# Out:
# S101    15.853659
# S102    18.699187
# S103    13.211382
# S104    17.886179
# S105    15.040650
# S106    19.308943
# Name: Marks, dtype: float64

# %%
stu = (marks/100)*100
print(stu)
# Out:
# S101    78.0
# S102    92.0
# S103    65.0
# S104    88.0
# S105    74.0
# S106    95.0
# Name: Marks, dtype: float64
