# %%
import pandas as pd

# %% [markdown]
# ##Task -1

# %%
marks = pd.Series(
   [78, 92, 65, 88, 74, 95],
   index=["S101", "S102", "S103", "S104", "S105", "S106"],
   name="Marks"
)

# %%
#1
print(marks)
# Out:
# S101    78
# S102    92
# S103    65
# S104    88
# S105    74
# S106    95
# Name: Marks, dtype: int64

# %%
#2
print(marks.index)
# Out:
# Index(['S101', 'S102', 'S103', 'S104', 'S105', 'S106'], dtype='object')

# %%
print(marks.values)
# Out:
# [78 92 65 88 74 95]

# %%
print(marks.dtype)
# Out:
# int64

# %%
print(marks.shape)
# Out:
# (6,)

# %%
print(marks.size)
# Out:
# 6

# %%
print(marks.ndim)
# Out:
# 1

# %%
print(marks.name)
# Out:
# Marks

# %%
#3
print(marks.mean())
# Out:
# 82.0

# %%
#4
print(marks.max())
# Out:
# 95

# %%
#5
print(marks.idxmax())
# Out:
# S106

# %%
#6
print(marks[marks>80])
# Out:
# S102    92
# S104    88
# S106    95
# Name: Marks, dtype: int64

# %%
marks.iloc[0:3]
# Out:
# S101    78
# S102    92
# S103    65
# Name: Marks, dtype: int64

# %%
print(marks.loc["S104"])
# Out:
# 88

# %%
#challenge
total = marks.sum()
per= (marks/total) *100
print(per)
# Out:
# S101    15.853659
# S102    18.699187
# S103    13.211382
# S104    17.886179
# S105    15.040650
# S106    19.308943
# Name: Marks, dtype: float64

# %%
stu = (marks/100)*100
print(stu)
# Out:
# S101    78.0
# S102    92.0
# S103    65.0
# S104    88.0
# S105    74.0
# S106    95.0
# Name: Marks, dtype: float64

# %% [markdown]
# *Task- 2*

# %%
prices = pd.Series(
        [1200, 850, 2300, 1750, 950, 3200],
        index=["P101", "P102", "P103", "P104", "P105", "P106"],
        name="Price"
        )

# %%
print(prices)
# Out:
# P101    1200
# P102     850
# P103    2300
# P104    1750
# P105     950
# P106    3200
# Name: Price, dtype: int64

# %%
#9
total = prices.sum()
print(total)
# Out:
# 10250

# %%
#10
print(prices.mean())
# Out:
# 1708.3333333333333

# %%
#11
print(prices.min())
# Out:
# 850

# %%
#12
print(prices.max())
# Out:
# 3200

# %%
#13
print(prices.idxmax(0))
# Out:
# P106

# %%
#14
print(prices[prices>1500])
# Out:
# P103    2300
# P104    1750
# P106    3200
# Name: Price, dtype: int64

# %%
#15
print(prices[(1000<prices) & (prices<2500)])
# Out:
# P101    1200
# P103    2300
# P104    1750
# Name: Price, dtype: int64

# %%
#16
prices = prices*1.10
print(prices)
# Out:
# P101    1320.0
# P102     935.0
# P103    2530.0
# P104    1925.0
# P105    1045.0
# P106    3520.0
# Name: Price, dtype: float64

# %%
#17
print(prices.nlargest(3))
# Out:
# P106    3520.0
# P103    2530.0
# P104    1925.0
# Name: Price, dtype: float64

# %%
employees = pd.DataFrame({
    "EmpID": ["E101", "E102", "E103", "E104", "E105"],  
    "Name": ["Rahul", "Priya", "Arun", "Meena", "Kiran"],    
    "Age": [25, 29, 24, 32, 27],    
    "Department": ["IT", "HR", "IT", "Sales", "Finance"],    
    "Salary": [45000, 55000, 48000, 70000, 85000]})

# %%
#18
print(employees)
# Out:
#   EmpID   Name  Age Department  Salary
# 0  E101  Rahul   25         IT   45000
# 1  E102  Priya   29         HR   55000
# 2  E103   Arun   24         IT   48000
# 3  E104  Meena   32      Sales   70000
# 4  E105  Kiran   27    Finance   85000

# %%
#19
print(employees.shape)
# Out:
# (5, 5)

# %%
print(employees.size)
# Out:
# 25

# %%
print(employees.ndim)
# Out:
# 2

# %%
print(employees.index)
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
print(employees.columns)
# Out:
# Index(['EmpID', 'Name', 'Age', 'Department', 'Salary'], dtype='object')

# %%
print(employees.values)
# Out:
# [['E101' 'Rahul' 25 'IT' 45000]
#  ['E102' 'Priya' 29 'HR' 55000]
#  ['E103' 'Arun' 24 'IT' 48000]
#  ['E104' 'Meena' 32 'Sales' 70000]
#  ['E105' 'Kiran' 27 'Finance' 85000]]

# %%
print(employees.dtypes)
# Out:
# EmpID         object
# Name          object
# Age            int64
# Department    object
# Salary         int64
# dtype: object

# %%
#20
print(employees["Name"])
# Out:
# 0    Rahul
# 1    Priya
# 2     Arun
# 3    Meena
# 4    Kiran
# Name: Name, dtype: object

# %%
#21
print(employees[["Name", "Salary"]])
# Out:
#     Name  Salary
# 0  Rahul   45000
# 1  Priya   55000
# 2   Arun   48000
# 3  Meena   70000
# 4  Kiran   85000

# %%
#22
print(employees.iloc[0:3])
# Out:
#   EmpID   Name  Age Department  Salary
# 0  E101  Rahul   25         IT   45000
# 1  E102  Priya   29         HR   55000
# 2  E103   Arun   24         IT   48000

# %%
#23
print(employees.iloc[:2:-1])
# Out:
#   EmpID   Name  Age Department  Salary
# 4  E105  Kiran   27    Finance   85000
# 3  E104  Meena   32      Sales   70000

# %%
#24
print(employees.iloc[1])
# Out:
# EmpID          E102
# Name          Priya
# Age              29
# Department       HR
# Salary        55000
# Name: 1, dtype: object

# %%
#25
print(employees.iloc[1]["Salary"])
# Out:
# 55000

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./orders2.csv")
print(data.head())
# Out:
#   Order_ID  Order_Date Customer_ID         Product     Category  Quantity  \
# 0   ORD051  2026-02-25     CUST051          Laptop  Electronics       1.0
# 1   ORD052  2026-02-26     CUST052  Wireless Mouse  Accessories       2.0
# 2   ORD053  2026-02-27     CUST053        Keyboard  Accessories       NaN
# 3   ORD054  2026-02-28     CUST054         Monitor  Electronics       1.0
# 4   ORD055  2026-03-01     CUST055      Headphones        Audio       2.0
#
#      Price       City  Revenue
# 0  72000.0  Hyderabad  72000.0
# 1   1400.0  Bangalore   2800.0
# 2   2800.0    Chennai      NaN
# 3      NaN     Mumbai      NaN
# 4   4200.0        NaN   8400.0

# %%
messy = data.copy()
print(messy.head())
# Out:
#   Order_ID  Order_Date Customer_ID         Product     Category  Quantity  \
# 0   ORD051  2026-02-25     CUST051          Laptop  Electronics       1.0
# 1   ORD052  2026-02-26     CUST052  Wireless Mouse  Accessories       2.0
# 2   ORD053  2026-02-27     CUST053        Keyboard  Accessories       NaN
# 3   ORD054  2026-02-28     CUST054         Monitor  Electronics       1.0
# 4   ORD055  2026-03-01     CUST055      Headphones        Audio       2.0
#
#      Price       City  Revenue
# 0  72000.0  Hyderabad  72000.0
# 1   1400.0  Bangalore   2800.0
# 2   2800.0    Chennai      NaN
# 3      NaN     Mumbai      NaN
# 4   4200.0        NaN   8400.0

# %%
miss_per = ( messy.isna().mean() *100)
print(miss_per)
# Out:
# Order_ID        1.960784
# Order_Date      1.960784
# Customer_ID     7.843137
# Product         1.960784
# Category        3.921569
# Quantity       15.686275
# Price          11.764706
# City           11.764706
# Revenue        25.490196
# dtype: float64

# %%
total_missing = messy.isna().sum()
print(total_missing)
total = total_missing.sum()
print(total)
# Out:
# Order_ID        1
# Order_Date      1
# Customer_ID     4
# Product         1
# Category        2
# Quantity        8
# Price           6
# City            6
# Revenue        13
# dtype: int64
# 42

# %%
rows_missing = messy[messy.isna().any(axis=1)]
print(rows_missing.count())
# Out:
# Order_ID       21
# Order_Date     21
# Customer_ID    18
# Product        21
# Category       20
# Quantity       14
# Price          16
# City           16
# Revenue         9
# dtype: int64

# %%
blank = messy[messy.isna().all(axis=1)]
print(blank)
# Out:
#    Order_ID Order_Date Customer_ID Product Category  Quantity  Price City  \
# 50      NaN        NaN         NaN     NaN      NaN       NaN    NaN  NaN
#
#     Revenue
# 50      NaN

# %%
clean = messy.dropna()
print(clean.shape)
print(clean)
# Out:
# (29, 9)
#    Order_ID  Order_Date Customer_ID              Product            Category  \
# 0    ORD051  2026-02-25     CUST051               Laptop         Electronics
# 1    ORD052  2026-02-26     CUST052       Wireless Mouse         Accessories
# 5    ORD056  2026-03-02     CUST056            USB Cable         Accessories
# 7    ORD058  2026-03-04     CUST058         External SSD             Storage
# 9    ORD060  2026-03-06     CUST060           Power Bank         Accessories
# 11   ORD062  2026-03-08     CUST062  Mechanical Keyboard         Accessories
# 13   ORD064  2026-03-10     CUST064               Tablet         Electronics
# 15   ORD066  2026-03-12     CUST066     Wireless Earbuds               Audio
# 16   ORD067  2026-03-13     CUST067           HDMI Cable         Accessories
# 18   ORD069  2026-03-15     CUST069         Office Chair           Furniture
# 19   ORD070  2026-03-16     CUST070            Mouse Pad         Accessories
# ...

# %%
clean_reveune = messy.dropna(subset=["Quantity", "Price"])
print(clean_reveune)
# Out:
#    Order_ID  Order_Date Customer_ID                      Product  \
# 0    ORD051  2026-02-25     CUST051                       Laptop
# 1    ORD052  2026-02-26     CUST052               Wireless Mouse
# 4    ORD055  2026-03-01     CUST055                   Headphones
# 5    ORD056  2026-03-02     CUST056                    USB Cable
# 6    ORD057  2026-03-03         NaN                       Webcam
# 7    ORD058  2026-03-04     CUST058                 External SSD
# 9    ORD060  2026-03-06     CUST060                   Power Bank
# 10   ORD061  2026-03-07     CUST061                 Laptop Stand
# 11   ORD062  2026-03-08     CUST062          Mechanical Keyboard
# 13   ORD064  2026-03-10     CUST064                       Tablet
# 14   ORD065  2026-03-11     CUST065                  Smart Watch
# 15   ORD066  2026-03-12     CUST066             Wireless Earbuds
# 16   ORD067  2026-03-13     CUST067                   HDMI Cable
# ...

# %%
print(messy.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Order_ID     50 non-null     object
#  1   Order_Date   50 non-null     object
#  2   Customer_ID  47 non-null     object
#  3   Product      50 non-null     object
#  4   Category     49 non-null     object
#  5   Quantity     43 non-null     float64
#  6   Price        45 non-null     float64
#  7   City         45 non-null     object
#  8   Revenue      38 non-null     float64
# dtypes: float64(3), object(6)
# memory usage: 3.7+ KB
# None

# %%
messy["City"]= messy["City"].fillna("Unknown")
print(messy["City"])
# Out:
# 0     Hyderabad
# 1     Bangalore
# 2       Chennai
# 3        Mumbai
# 4       Unknown
# 5          Pune
# 6     Hyderabad
# 7     Bangalore
# 8       Chennai
# 9        Mumbai
# 10        Delhi
# 11         Pune
# 12    Hyderabad
# 13    Bangalore
# 14      Unknown
# 15       Mumbai
# 16        Delhi
# 17         Pune
# 18    Hyderabad
# 19    Bangalore
# 20      Chennai
# 21       Mumbai
# 22        Delhi
# 23         Pune
# 24      Unknown
# 25    Hyderabad
# 26    Bangalore
# 27      Chennai
# 28       Mumbai
# 29        Delhi
# 30         Pune
# 31    Hyderabad
# 32    Bangalore
# 33      Chennai
# 34       Mumbai
# 35        Delhi
# 36         Pune
# 37      Unknown
# 38    Hyderabad
# 39    Bangalore
# 40      Chennai
# 41       Mumbai
# 42        Delhi
# 43         Pune
# 44    Hyderabad
# 45      Unknown
# 46    Bangalore
# 47      Chennai
# 48       Mumbai
# 49        Delhi
# 50      Unknown
# Name: City, dtype: object

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.2

# %%
data = pd.read_csv("./Pandas_Dataset.csv")

# %%
data.head()
# Out:
#   Transaction_ID Transaction_Date Region     Category  Product  \
# 0        TXN0001       2025-08-03   East     Clothing    Shoes
# 1        TXN0002       2025-07-11   West    Groceries      Oil
# 2        TXN0003       2025-06-19   West    Groceries   Coffee
# 3        TXN0004       2025-11-25   East    Groceries   Snacks
# 4        TXN0005       2025-04-02   East  Electronics  Monitor
#
#   Customer_Segment  Quantity  Unit_Price   Revenue      Cost  \
# 0      Home Office         5     2896.10  14480.49  11108.36
# 1         Consumer         3      642.13   1926.39   1565.73
# 2      Home Office         6      553.88   3323.27   1945.89
# 3        Corporate         4      308.32   1233.27    729.05
# 4      Home Office         6    16387.79  98326.73  64217.91
#
#    Discount_Percent  Customer_Rating Payment_Method
# 0              20.0              2.9    Net Banking
# 1              15.0              4.8    Credit Card
# 2              10.0              4.0     Debit Card
# ...

# %%
data.shape
# Out:
# (242, 13)

# %%
data.columns
# Out:
# Index(['Transaction_ID', 'Transaction_Date', 'Region', 'Category', 'Product',
#        'Customer_Segment', 'Quantity', 'Unit_Price', 'Revenue', 'Cost',
#        'Discount_Percent', 'Customer_Rating', 'Payment_Method'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Transaction_ID       object
# Transaction_Date     object
# Region               object
# Category             object
# Product              object
# Customer_Segment     object
# Quantity              int64
# Unit_Price          float64
# Revenue             float64
# Cost                float64
# Discount_Percent    float64
# Customer_Rating     float64
# Payment_Method       object
# dtype: object

# %%
data.describe()
# Out:
#          Quantity    Unit_Price        Revenue           Cost  \
# count  242.000000    242.000000     242.000000     242.000000
# mean     4.041322  10322.179298   38927.208760   27191.241942
# std      2.046743  15668.991597   68347.099212   47858.960943
# min      1.000000    257.730000     257.730000     194.300000
# 25%      2.000000    856.407500    3497.757500    2465.900000
# 50%      4.000000   3246.585000   12483.485000    8856.110000
# 75%      6.000000  12531.182500   44240.565000   31006.142500
# max      7.000000  73826.650000  485862.050000  350943.550000
#
#        Discount_Percent  Customer_Rating
# count        240.000000       239.000000
# mean          11.354167         3.733891
# std            6.575883         0.723366
# min            0.000000         2.500000
# 25%            5.000000         3.100000
# 50%           10.000000         3.800000
# 75%           15.000000         4.300000
# max           20.000000         5.000000

# %%
data.nunique()
# Out:
# Transaction_ID      240
# Transaction_Date    182
# Region                7
# Category              4
# Product              16
# Customer_Segment      3
# Quantity              7
# Unit_Price          240
# Revenue             240
# Cost                240
# Discount_Percent      5
# Customer_Rating      26
# Payment_Method        8
# dtype: int64

# %%
data.shape
# Out:
# (242, 13)

# %%
print(data.isna().sum())
# Out:
# Transaction_ID      0
# Transaction_Date    0
# Region              0
# Category            0
# Product             0
# Customer_Segment    0
# Quantity            0
# Unit_Price          0
# Revenue             0
# Cost                0
# Discount_Percent    2
# Customer_Rating     3
# Payment_Method      0
# dtype: int64

# %%
print(data.isna().mean()*100)
# Out:
# Transaction_ID      0.000000
# Transaction_Date    0.000000
# Region              0.000000
# Category            0.000000
# Product             0.000000
# Customer_Segment    0.000000
# Quantity            0.000000
# Unit_Price          0.000000
# Revenue             0.000000
# Cost                0.000000
# Discount_Percent    0.826446
# Customer_Rating     1.239669
# Payment_Method      0.000000
# dtype: float64

# %%
data.nunique()
# Out:
# Transaction_ID      240
# Transaction_Date    182
# Region                7
# Category              4
# Product              16
# Customer_Segment      3
# Quantity              7
# Unit_Price          240
# Revenue             240
# Cost                240
# Discount_Percent      5
# Customer_Rating      26
# Payment_Method        8
# dtype: int64

# %%
quality_report = pd.DataFrame({
    "Data Type" : data.dtypes,
    "Missing Count": data.isna().sum(),
    "Missing Percentage" : data.isna().mean()*100,
    "Unique Values" : data.nunique()
})

print(quality_report)
# Out:
#                  Data Type  Missing Count  Missing Percentage  Unique Values
# Transaction_ID      object              0            0.000000            240
# Transaction_Date    object              0            0.000000            182
# Region              object              0            0.000000              7
# Category            object              0            0.000000              4
# Product             object              0            0.000000             16
# Customer_Segment    object              0            0.000000              3
# Quantity             int64              0            0.000000              7
# Unit_Price         float64              0            0.000000            240
# Revenue            float64              0            0.000000            240
# Cost               float64              0            0.000000            240
# Discount_Percent   float64              2            0.826446              5
# ...

# %% [markdown]
# task 3

# %%
data["Region"].unique()
# Out:
# array(['East', 'West', 'South', 'south', 'North', 'WEST', 'North '],
#       dtype=object)

# %%
data["Region"]= data["Region"].str.strip().str.title()
print(data['Region'].unique())
# Out:
# ['East' 'West' 'South' 'North']

# %%
data["Region"].value_counts()
# Out:
# Region
# North    78
# East     55
# South    55
# West     54
# Name: count, dtype: int64

# %% [markdown]
# task 4

# %%
data["Payment_Method"].unique()
# Out:
# array(['Net Banking', 'Credit Card', 'Debit Card', 'Cash', 'UPI', 'upi',
#        'Credit card', 'UPI '], dtype=object)

# %%
data["Payment_Method"] = data["Payment_Method"].str.strip().str.title()

# %%
print(data["Payment_Method"].unique())
# Out:
# ['Net Banking' 'Credit Card' 'Debit Card' 'Cash' 'Upi']

# %%
print(data["Payment_Method"].value_counts())
# Out:
# Payment_Method
# Credit Card    53
# Cash           52
# Net Banking    48
# Upi            47
# Debit Card     42
# Name: count, dtype: int64

# %%
print(data["Payment_Method"].count())
# Out:
# 242

# %%
data[["Customer_Rating", "Discount_Percent"]].isna().sum()
# Out:
# Customer_Rating     3
# Discount_Percent    2
# dtype: int64

# %%
print(data["Customer_Rating"].median())
# Out:
# 3.8

# %%
data["Customer_Rating"] = data["Customer_Rating"].fillna(data["Customer_Rating"].median())

# %%
print(data["Customer_Rating"].isna().sum())
# Out:
# 0

# %%
data["Discount_Percent"] = data["Discount_Percent"].fillna(0)

# %%
print(data["Discount_Percent"].isna().sum())
# Out:
# 0

# %%
data[["Customer_Rating", "Discount_Percent"]].isna().sum()
# Out:
# Customer_Rating     0
# Discount_Percent    0
# dtype: int64

# %% [markdown]
# Task 6

# %%
print(data.duplicated().sum())
# Out:
# 2

# %%
print(data["Transaction_ID"].duplicated().sum())
# Out:
# 2

# %%
print(data["Transaction_ID"].duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 237    False
# 238    False
# 239    False
# 240     True
# 241     True
# Name: Transaction_ID, Length: 242, dtype: bool

# %%
data[data["Transaction_ID"].duplicated(keep=False)]
# Out:
#     Transaction_ID Transaction_Date Region     Category     Product  \
# 50         TXN0051       2025-10-11  South     Clothing      Jacket
# 151        TXN0152       2025-01-27   East  Electronics  Headphones
# 240        TXN0051       2025-10-11  South     Clothing      Jacket
# 241        TXN0152       2025-01-27   East  Electronics  Headphones
#
#     Customer_Segment  Quantity  Unit_Price   Revenue      Cost  \
# 50       Home Office         1     2424.93   2424.93   1964.31
# 151         Consumer         4     3856.94  15427.78  11809.62
# 240      Home Office         1     2424.93   2424.93   1964.31
# 241         Consumer         4     3856.94  15427.78  11809.62
#
#      Discount_Percent  Customer_Rating Payment_Method
# 50               10.0              2.7           Cash
# 151              15.0              4.1           Cash
# 240              10.0              2.7           Cash
# 241              15.0              4.1           Cash

# %%
data = data.drop_duplicates(subset="Transaction_ID")

# %%
data[data["Transaction_ID"].duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Transaction_ID, Transaction_Date, Region, Category, Product, Customer_Segment, Quantity, Unit_Price, Revenue, Cost, Discount_Percent, Customer_Rating, Payment_Method]
# Index: []

# %%
data.shape
# Out:
# (240, 13)

# %%
print(data["Transaction_ID"].duplicated().sum())
# Out:
# 0

# %% [markdown]
# task7

# %%
filtered_data = data[
    (data["Revenue"] > 50000) &
    (data["Region"].isin(["North", "West"])) &
    (data["Quantity"] >= 5)
]

# %%
print(filtered_data)
# Out:
#     Transaction_ID Transaction_Date Region     Category       Product  \
# 14         TXN0015       2025-11-27   West    Furniture  Office Chair
# 16         TXN0017       2025-04-06   West  Electronics    Smartphone
# 27         TXN0028       2025-02-02   West  Electronics    Smartphone
# 31         TXN0032       2025-06-10   West    Furniture  Office Chair
# 43         TXN0044       2025-01-04   West    Furniture         Table
# 63         TXN0064       2025-05-26   West    Furniture          Desk
# 65         TXN0066       2025-01-23  North  Electronics       Monitor
# 77         TXN0078       2025-03-19   West  Electronics       Monitor
# 91         TXN0092       2025-02-11  North  Electronics        Laptop
# 98         TXN0099       2025-11-20  North  Electronics        Laptop
# 118        TXN0119       2025-12-29  North  Electronics    Smartphone
# 120        TXN0121       2025-09-07   West    Furniture          Desk
# ...

# %%
print(filtered_data.shape)
# Out:
# (23, 13)

# %% [markdown]
# Task 8

# %%
data.sort_values("Revenue", ascending=False)
# Out:
#     Transaction_ID Transaction_Date Region     Category Product  \
# 98         TXN0099       2025-11-20  North  Electronics  Laptop
# 225        TXN0226       2025-08-08  North  Electronics  Laptop
# 40         TXN0041       2025-03-17  South  Electronics  Laptop
# 80         TXN0081       2025-05-26   East  Electronics  Laptop
# 132        TXN0133       2025-10-20  North  Electronics  Laptop
# ..             ...              ...    ...          ...     ...
# 60         TXN0061       2025-01-08  South    Groceries  Snacks
# 189        TXN0190       2025-10-02  South    Groceries  Snacks
# 205        TXN0206       2025-05-22   West    Groceries  Snacks
# 126        TXN0127       2025-12-01  North    Groceries  Snacks
# 181        TXN0182       2025-05-27   East    Groceries  Snacks
#
#     Customer_Segment  Quantity  Unit_Price    Revenue       Cost  \
# 98          Consumer         7    69408.86  485862.05  350943.55
# ...

# %%
data = data.sort_values("Revenue", ascending=False)

# %%
data["Profit"] = data["Revenue"] - data["Cost"]

# %%
print(data["Profit"])
# Out:
# 98     134918.50
# 225    172973.19
# 40      99916.29
# 80      85875.35
# 132    102171.28
#          ...
# 60         64.07
# 189       103.21
# 205        92.42
# 126        76.95
# 181        50.66
# Name: Profit, Length: 240, dtype: float64

# %%
data.sort_values("Profit", ascending=False)
# Out:
#     Transaction_ID Transaction_Date Region     Category Product  \
# 225        TXN0226       2025-08-08  North  Electronics  Laptop
# 98         TXN0099       2025-11-20  North  Electronics  Laptop
# 132        TXN0133       2025-10-20  North  Electronics  Laptop
# 40         TXN0041       2025-03-17  South  Electronics  Laptop
# 80         TXN0081       2025-05-26   East  Electronics  Laptop
# ..             ...              ...    ...          ...     ...
# 189        TXN0190       2025-10-02  South    Groceries  Snacks
# 205        TXN0206       2025-05-22   West    Groceries  Snacks
# 126        TXN0127       2025-12-01  North    Groceries  Snacks
# 60         TXN0061       2025-01-08  South    Groceries  Snacks
# 181        TXN0182       2025-05-27   East    Groceries  Snacks
#
#     Customer_Segment  Quantity  Unit_Price    Revenue       Cost  \
# 225      Home Office         6    71445.42  428672.53  255699.34
# ...

# %% [markdown]
# Task 9

# %%
print(data["Profit"].sum())
# Out:
# 2836025.1900000004

# %%
print(data["Profit"].mean())
# Out:
# 11816.771625000001

# %%
profit_margin = (
    data["Profit"].sum() /
    data["Revenue"].sum()
) * 100

# %%
print(profit_margin)
# Out:
# 30.162356770585607

# %%
total_profit = data["Profit"].sum()
average_profit = data["Profit"].mean()
profit_margin = (data["Profit"].sum() / data["Revenue"].sum()) * 100

# %%
print(total_profit)
# Out:
# 2836025.1900000004

# %%
print(average_profit)
# Out:
# 11816.771625000001

# %%
print(profit_margin)
# Out:
# 30.162356770585607

# %% [markdown]
# Task 10

# %%
data.groupby("Region")["Revenue"].sum()
# Out:
# Region
# East     1801974.10
# North    3233218.56
# South    2054204.14
# West     2313135.01
# Name: Revenue, dtype: float64

# %%
data.groupby("Region")["Cost"].sum()
# Out:
# Region
# East     1267152.47
# North    2216529.77
# South    1438355.22
# West     1644469.16
# Name: Cost, dtype: float64

# %%
data.groupby("Region")["Customer_Rating"].mean()
# Out:
# Region
# East     3.783333
# North    3.710256
# South    3.598148
# West     3.870370
# Name: Customer_Rating, dtype: float64

# %%
region_summary = data.groupby("Region").agg(
    Total_Revenue=("Revenue", "sum"),
    Total_Cost=("Cost", "sum"),
    Total_Profit=("Profit", "sum"),
    Average_Rating=("Customer_Rating", "mean")
)

# %%
print(region_summary)
# Out:
#         Total_Revenue  Total_Cost  Total_Profit  Average_Rating
# Region
# East       1801974.10  1267152.47     534821.63        3.783333
# North      3233218.56  2216529.77    1016688.79        3.710256
# South      2054204.14  1438355.22     615848.92        3.598148
# West       2313135.01  1644469.16     668665.85        3.870370

# %% [markdown]
# Task 11

# %%
region_category_summary = data.groupby(
    ["Region", "Category"]
).agg(
    Total_Revenue=("Revenue", "sum"),
    Total_Cost=("Cost", "sum"),
    Total_Profit=("Profit", "sum")
).reset_index()

# %%
print(region_category_summary)
# Out:
#    Region     Category  Total_Revenue  Total_Cost  Total_Profit
# 0    East     Clothing       90993.22    62160.56      28832.66
# 1    East  Electronics     1204820.29   876586.23     328234.06
# 2    East    Furniture      457433.14   294671.64     162761.50
# 3    East    Groceries       48727.45    33734.04      14993.41
# 4   North     Clothing      140567.76   100481.88      40085.88
# 5   North  Electronics     2510826.64  1724216.03     786610.61
# 6   North    Furniture      512729.66   343707.60     169022.06
# 7   North    Groceries       69094.50    48124.26      20970.24
# 8   South     Clothing      109951.01    74176.86      35774.15
# 9   South  Electronics     1307499.18   915951.36     391547.82
# 10  South    Furniture      601336.22   423919.18     177417.04
# 11  South    Groceries       35417.73    24307.82      11109.91
# 12   West     Clothing       53787.10    36268.56      17518.54
# 13   West  Electronics     1244182.60   886888.88     357293.72
# ...

# %%
data.groupby(["Region", "Category"])["Revenue"].sum()
# Out:
# Region  Category
# East    Clothing         90993.22
#         Electronics    1204820.29
#         Furniture       457433.14
#         Groceries        48727.45
# North   Clothing        140567.76
#         Electronics    2510826.64
#         Furniture       512729.66
#         Groceries        69094.50
# South   Clothing        109951.01
#         Electronics    1307499.18
#         Furniture       601336.22
#         Groceries        35417.73
# West    Clothing         53787.10
#         Electronics    1244182.60
#         Furniture       965843.47
#         Groceries        49321.84
# Name: Revenue, dtype: float64

# %%
data.groupby(["Region", "Category"])["Cost"].sum()
# Out:
# Region  Category
# East    Clothing         62160.56
#         Electronics     876586.23
#         Furniture       294671.64
#         Groceries        33734.04
# North   Clothing        100481.88
#         Electronics    1724216.03
#         Furniture       343707.60
#         Groceries        48124.26
# South   Clothing         74176.86
#         Electronics     915951.36
#         Furniture       423919.18
#         Groceries        24307.82
# West    Clothing         36268.56
#         Electronics     886888.88
#         Furniture       686391.81
#         Groceries        34919.91
# Name: Cost, dtype: float64

# %%
data.groupby(["Region", "Category"])["Profit"].sum()
# Out:
# Region  Category
# East    Clothing        28832.66
#         Electronics    328234.06
#         Furniture      162761.50
#         Groceries       14993.41
# North   Clothing        40085.88
#         Electronics    786610.61
#         Furniture      169022.06
#         Groceries       20970.24
# South   Clothing        35774.15
#         Electronics    391547.82
#         Furniture      177417.04
#         Groceries       11109.91
# West    Clothing        17518.54
#         Electronics    357293.72
#         Furniture      279451.66
#         Groceries       14401.93
# Name: Profit, dtype: float64

# %%
print(region_category_summary)
# Out:
#    Region     Category  Total_Revenue  Total_Cost  Total_Profit
# 0    East     Clothing       90993.22    62160.56      28832.66
# 1    East  Electronics     1204820.29   876586.23     328234.06
# 2    East    Furniture      457433.14   294671.64     162761.50
# 3    East    Groceries       48727.45    33734.04      14993.41
# 4   North     Clothing      140567.76   100481.88      40085.88
# 5   North  Electronics     2510826.64  1724216.03     786610.61
# 6   North    Furniture      512729.66   343707.60     169022.06
# 7   North    Groceries       69094.50    48124.26      20970.24
# 8   South     Clothing      109951.01    74176.86      35774.15
# 9   South  Electronics     1307499.18   915951.36     391547.82
# 10  South    Furniture      601336.22   423919.18     177417.04
# 11  South    Groceries       35417.73    24307.82      11109.91
# 12   West     Clothing       53787.10    36268.56      17518.54
# 13   West  Electronics     1244182.60   886888.88     357293.72
# ...

# %% [markdown]
# Task 12

# %%
revenue_pivot = pd.pivot_table(
    data,
    values="Revenue",
    index="Region",
    columns="Category",
    aggfunc="sum"
)

revenue_pivot
# Out:
# Category   Clothing  Electronics  Furniture  Groceries
# Region
# East       90993.22   1204820.29  457433.14   48727.45
# North     140567.76   2510826.64  512729.66   69094.50
# South     109951.01   1307499.18  601336.22   35417.73
# West       53787.10   1244182.60  965843.47   49321.84

# %%
rating_pivot = pd.pivot_table(
    data,
    values="Customer_Rating",
    index="Category",
    aggfunc="mean"
)

rating_pivot
# Out:
#              Customer_Rating
# Category
# Clothing            3.807547
# Electronics         3.791525
# Furniture           3.626230
# Groceries           3.735821

# %%
profit_pivot = pd.pivot_table(
    data,
    values="Profit",
    index="Customer_Segment",
    columns="Region",
    aggfunc="sum"
)

profit_pivot
# Out:
# Region                 East      North      South       West
# Customer_Segment
# Consumer           80054.06  422584.15  229142.50  228929.83
# Corporate         120363.55  271460.86  177455.46  277879.98
# Home Office       334404.02  322643.78  209250.96  161856.04

# %%
pd.pivot_table(
    data,
    values="Revenue",
    index="Region",
    columns="Category",
    aggfunc="sum"
)
# Out:
# Category   Clothing  Electronics  Furniture  Groceries
# Region
# East       90993.22   1204820.29  457433.14   48727.45
# North     140567.76   2510826.64  512729.66   69094.50
# South     109951.01   1307499.18  601336.22   35417.73
# West       53787.10   1244182.60  965843.47   49321.84
