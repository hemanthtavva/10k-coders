# %%
import numpy as np

# %%
#numpy zeroes()
# it creates a array illed with xeroes, by default it is stored in float value,
#but we can modify it by declaring the data type,
# it is useful in some cases example:-
