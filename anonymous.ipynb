# %%
add = lambda a,b : a+b
print(add(2,4))
# Out:
# 6

# %%
mul = lambda a,b : a * b
print(mul(5,4))
# Out:
# 20

# %%
is_even = lambda n : n%2 == 0
print(is_even(8))
print(is_even(7))
# Out:
# True
# False
