# %%
#1. Define a lambda function to square each number in a given list of integers.

nums = [1, 2, 3, 4, 5]
square =[]
def square_list(nums):
    for i in nums:
        square = lambda x : x**2
        square.append(square(i))
        return square

def square_list(nums):
    return [x ** 2 for x in nums]

square_list(nums)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 11
#       8         square.append(square(i))
#       9         return square
# ---> 11 square_list(nums)
#
# Cell In[9], line 8, in square_list(nums)
#       6 for i in nums:
#       7     square = lambda x : x**2
# ----> 8     square.append(square(i))
#       9     return square
#
# AttributeError: 'function' object has no attribute 'append'
