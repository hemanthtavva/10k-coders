# %%
#  encapsulation is binding the data and the methods that operate on that data into single unit called class. 
#  Encapsulation helps to protect the internal state of an object from unintended interference and misuse by restricting access to its internal representation.
#  This is typically achieved by using access modifiers (like private, protected, and public) to control the visibility of class members (attributes and methods).

# %%
class car:
    def__init__(self, color, top_speed, model, mileage, brand):
        self.__color = color
        self.__top_speed = top_speed
        self.__model = model
        self.__mileage = mileage
        self.__brand = brand
# Out:
#   Cell In[1], line 2
#     def__init__(self, color, top_speed, model, mileage, brand):
#                                                               ^
# SyntaxError: invalid syntax

# %%
class BankAccount:                                      
    def __init__(self, acc_holder, balance,password):            
        self.acc_holder = acc_holder
        self.balance = balance
        self.password=password

    def deposit(self, amount):
        self.balance += amount
        print("Amount deposited to your account.")

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient funds.")
        else:
            self.balance -= amount
            print("Amount withdrawn from your account.")
            print("withdraw successfully!")


    def show_bal(self):
        print("Current Balance:", self.balance)


print("=" * 50)
print("Enter the Details")
print("=" * 50)

name = input("Enter the name of the account holder: ")
balance = float(input("Enter the initial balance: "))
p=input("enter the password: ")

acc = BankAccount(name, balance, p)

print("\nChoose an option")
print("1. Deposit")
print("2. Withdraw")
print("3. Check Balance")

op = int(input("Enter your choice: "))

match op:
    case 1:
        amount = float(input("Enter deposit amount: "))
        acc.deposit(amount)
        print("deposit successfully!")

    case 2:
        amount = float(input("Enter withdrawal amount: "))
        acc.withdraw(amount)
    case 3:
        print("enter the password:")
        p=input("enter the password")
        if acc.password==p:
            acc.show_bal()
        else:
            print("invalid password!!")

    case _:
        print("Invalid choice.")
# Out:
# ...
# Enter the Details
# ...
#
# Choose an option
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# enter the password:
# Current Balance: 50000.0
