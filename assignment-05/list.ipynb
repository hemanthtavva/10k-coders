# %%
#Implement a Python function remove_duplicates that takes a list as input, removes duplicate elements, and returns the resulting list.
def rem_dup(lst):
    seen = []
    for i in lst:
        if i not in seen:
            seen.append(i)
    return seen

result = rem_dup(input_list)
print(result)
    # return list(set(lst))
# # Example usage:
# input_list = [1, 2, 3, 4, 2, 3, 5]
# result = rem_dup(input_list)
# print(result)  # Output: [1, 2, 3, 4, 5]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 9
#       6             seen.append(i)
#       7     return seen
# ----> 9 result = rem_dup(int(input()))
#      10 print(result)
#      11     # return list(set(lst))
#      12 # # Example usage:
#      13 # input_list = [1, 2, 3, 4, 2, 3, 5]
#      14 # result = rem_dup(input_list)
#      15 # print(result)  # Output: [1, 2, 3, 4, 5]
#
# ValueError: invalid literal for int() with base 10: '1 2 3 4 5 3 2 4 3 3'
