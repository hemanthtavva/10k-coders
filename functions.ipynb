# %%
print('hi')
# Out:
# hi

# %%
a = int(input())
b = int(input())
def add_2_num(a, b):
    print(a+b)
add_2_num(a,b)
# Out:
# 3

# %%
#sample login and showing reels using functions
reg_username= "Hemanth" 
reg_password= "hemanth"
username = input()
password = input()
def user_login(username, password):
    if username == reg_username and password == reg_password :
        return True
    else:
        return False
user_login(reg_username, reg_password)

def show_reels(is_logged_in):
    if is_logged_in == True:
        print("Showing Reels")
    else:
        print("please login first")
show_reels(user_login(reg_username, reg_password))
# Out:
# Showing Reels
